# %% [markdown]
# <a href="https://colab.research.google.com/github/lakkireddylahari-bot/data-science-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
arr = np.array([[1,2,3,4,5],[4,5,6,7,8]])
print(arr)
print(arr.sum(axis =0))
print(arr.sum(axis =1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_376/166559829.py in <cell line: 0>()
# ----> 1 arr = np .array([[1,2,3,4,5],[4,5,6,7,8]])
#       2 print(arr)
#       3 print(arr.sum(axis =0))
#       4 print(arr.sum(axis =1))
#
# NameError: name 'np' is not defined

# %%
import numpy as np
# indexing
l = [10,20,30,40]
arr = np.array(l)
print(arr[3])
print(arr[0])
print(arr[1])
print(arr[-1])
# Out:
# 40
# 10
# 20
# 40

# %%
import numpy as np
l2 = [[1,2,3],
       [4,5,6],
       [7,8,9]
]
l2 = np.array(l2)
print(l2)
print(l2[0,0])
print(l2[2,2])
print(l2[1,0])
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# 1
# 9
# 4
